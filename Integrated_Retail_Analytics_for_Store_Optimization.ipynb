# %% [markdown]
# <a href="https://colab.research.google.com/github/bsshewale/Building-Travel-Insights-Web-App-using-Streamlit/blob/main/Integrated_Retail_Analytics_for_Store_Optimization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project Objective:
#
# To utilize machine learning and data analysis techniques to optimize store performance, forecast demand, and enhance customer experience through segmentation and personalized marketing strategies.

# %%
# Import drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Importing libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Loading the data
df=pd.read_csv('/content/drive/MyDrive/Masters projects/Integrated Retail Analytics for Store Optimization and Demand Forecasting/Copy of Features data set.csv')

df1=pd.read_csv('/content/drive/MyDrive/Masters projects/Integrated Retail Analytics for Store Optimization and Demand Forecasting/Copy of sales data-set.csv')

df2=pd.read_csv('/content/drive/MyDrive/Masters projects/Integrated Retail Analytics for Store Optimization and Demand Forecasting/Copy of stores data-set.csv')
